# %% [markdown]
# <h1>Final Project: Resources Allocation</h1>

# %% [markdown]
# <h3>Introduction</h3>

# %% [markdown]
# <h6>Problem Identification<h6>

# %% [markdown]
# The current problem is well known for all human beings, which is how to deal with CoronaVirus.
# It is worth to mention that after the complete lockdown in most countries around the world to avoid further spread of the virus; our main problem become how to equally allocate primary needs for all human beings

# %% [markdown]
# My approach is to point out the availability of markets and stores that can provide the necessary foods and beverages required to avoid any miss guided information regarding the inability of obtaining the necessary needs

# %% [markdown]
# It is required to access the FourSquare Database to obtain the needed information required to complete my project

# %% [markdown]
# My Project will compare between the availability of markets in New york - USA

# %% [markdown]
# My Project will be based on Providing a map for New York state pointing out the available markets that sells the necessary Food and Beverages

# %% [markdown]
# The model will then be published for assessment as it will serve as a reference to find the necessary stores and obtain the needed requirements

# %% [markdown]
# Finally, according to the feedbacks, i will evaluate the points of strength and weakness in the provided information and will work on enhancing the data provided
